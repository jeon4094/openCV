# %%
from google.colab import drive
import cv2
from google.colab.patches import cv2_imshow
import numpy as np
import matplotlib.pyplot as plt

# %%
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
img = cv2.imread('/content/drive/MyDrive/Colab Notebooks/ch02/pic.jpg')
RGB_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
cv2.split(RGB_img)
# Out:
# (array([[253, 255, 255, ..., 242, 242, 242],
#         [254, 255, 255, ..., 242, 242, 242],
#         [255, 255, 255, ..., 242, 242, 242],
#         ...,
#         [248, 248, 248, ..., 248, 248, 248],
#         [247, 247, 247, ..., 248, 248, 248],
#         [247, 247, 247, ..., 248, 248, 248]], dtype=uint8),
#  array([[111, 113, 113, ..., 240, 240, 240],
#         [112, 113, 113, ..., 240, 240, 240],
#         [113, 113, 113, ..., 240, 240, 240],
#         ...,
#         [248, 248, 248, ..., 248, 248, 248],
#         [248, 248, 248, ..., 248, 248, 248],
#         [248, 248, 248, ..., 248, 248, 248]], dtype=uint8),
#  array([[167, 169, 169, ..., 245, 245, 245],
#         [168, 169, 169, ..., 245, 245, 245],
#         [169, 169, 169, ..., 245, 245, 245],
#         ...,
#         [250, 250, 250, ..., 250, 250, 250],
#         [250, 250, 250, ..., 250, 250, 250],
#         [250, 250, 250, ..., 250, 250, 250]], dtype=uint8))

# %%
img = cv2.imread('/content/drive/MyDrive/Colab Notebooks/ch02/pic.jpg')
RGB_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(RGB_img)
